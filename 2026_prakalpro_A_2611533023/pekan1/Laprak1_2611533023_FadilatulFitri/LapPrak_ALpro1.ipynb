# %% [markdown]
# <div align="center">
#
# **LAPORAN PRAKTIKUM**
#
# **Algoritma dan Pemograman**
#
# **“Pengenalan python, VScode, dan koneksi ke github”**
#
# **Disusun Oleh :**
#
# **Fadilatul Fitri**
#
# **2611533023**
#
# **Dosen Pengampu:**
#
# **Wahyudi.DR.. S.T.M.T**
#
# **Asisten Praktikum:**
#
# **Sherly Sukmadira**
#
# <br>
#
#  <img src="images/logo_unand.png" width="200">
#
# <br>
#
# **FAKULTAS TEKNOLOGI INFORMASI**
#
# **DEPARTEMEN INFORMATIKA**
#
# **UNIVERSITAS ANDALAS**
#
# **2026**
#
# </div>

# %% [markdown]
# ## KATA PENGANTAR
#
# Puji syukur penulis panjatkan atas kehadirat Tuhan Yang Maha Esa yang telah memberikan rahmat dan berkatnya, sehingga penulis dapat menyelesaikan laporan praktikum Pengenalan python, VScode, dan koneksi ke github yang telah dilaksanakan sebagai pertemuan ke-1 untuk mata kuliah Praktikum Struktur Data. Praktikum ini berfokus pada pembahasan cara memasang VScode, python, dan mengkomitkan ke github.
# Melalui praktikum ini, hasil yang diharapkan adalah penulis dapat memahami dan mengimplementasikan secara langsung konsep dasar penggunaan Python, VScode, serta GitHub pada real project.
#
# Penulis menyadari bahwa laporan praktikum ini masih memiliki banyak kekurangan. Oleh karena itu, kritik dan saran yang membangun sangat diharapkan demi perbaikan dan pengembangan di masa mendatang.
#
# Padang, 2026

# %% [markdown]
# ---
# # BAB I
# # PENDAHULUAN
#
# ## 1.1 Latar Belakang
# Dalam perkembangan teknologi saat ini, kemampuan pemrograman merupakan salah satu keterampilan yang penting bagi mahasiswa di bidang teknologi informasi. Dalam proses pemrograman, tidak hanya diperlukan pemahaman mengenai bahasa pemrograman, tetapi juga kemampuan dalam menggunakan perangkat lunak dan platform yang mendukung proses pengembangan program. Oleh karena itu, pemahaman mengenai Python, Visual Studio Code (VS Code), dan GitHub merupakan dasar yang penting untuk dipelajari.
#
# Python merupakan salah satu bahasa pemrograman yang banyak digunakan karena memiliki sintaks yang relatif sederhana dan mudah dipahami. Python juga dapat digunakan untuk mengembangkan berbagai jenis program dalam berbagai bidang. VS Code berfungsi sebagai perangkat lunak untuk menulis, mengedit, dan menjalankan kode program. Sementara itu, GitHub digunakan untuk menyimpan dan mengelola kode program serta mendukung proses pengelolaan perubahan dan kolaborasi dalam suatu proyek. Ketiganya memiliki fungsi yang saling berkaitan dalam proses pengembangan program.
#
# Melalui praktikum ini, mahasiswa diperkenalkan pada proses instalasi dan penggunaan Python serta VS Code, kemudian menghubungkannya dengan GitHub untuk mengelola proyek pemrograman. Pemahaman mengenai penggunaan ketiga perangkat tersebut diharapkan dapat membantu mahasiswa menerapkan proses pengembangan program secara lebih terstruktur, baik dalam pengerjaan tugas maupun dalam pengembangan proyek nyata.
#
# ## 1.2 Tujuan
# 1. Mengetahui cara memasang dan menggunakan Python serta VScode dengan benar.
# 2. Memahami cara menghubungkan proyek yang dibuat dengan GitHub.
# 3. Mampu menerapkan penggunaan Python, VScode dan GitHub dalam pengerjaan suatu proyek.
#
# ## 1.3 Manfaat
# 1. Menambah pengetahuan dan kemampuan dalam menggunakan Python, VS code, dan GitHub.
# 2. Membantu mahasiswa/i mengerjakan tugas atau proyek secara teratur.
# 3. Membantu mahasiswa/i menerapkan pengetahuan yang diperoleh dalam praktikum pada pembuatan proyek sederhana sehingga dapat menjadi dasar untuk mengerjakan proyek pemograman berikutnya.

# %% [markdown]
# ---
# # BAB II
# # PEMBAHASAN
#
# ## 2.1 Dasar Teori
# Praktikum ini didasarkan pada beberapa konsep dasar yang berkaitan dengan Python, Visual Studio Code (VS Code), Git, dan GitHub. Konsep-konsep tersebut menjadi dasar dalam proses pembuatan, pengelolaan, serta penyimpanan suatu proyek. Pemahaman terhadap setiap konsep diperlukan agar praktikum dapat dilaksanakan dengan baik. konsep-konsep yang digunakan waktu praktikum minggu pertama yaitu:
#
# 1. Python merupakan bahasa pemrograman yang digunakan untuk memberikan perintah kepada komputer dalam menyelesaikan suatu pekerjaan. Python memiliki sintaks yang sederhana dan mudah dipahami.
# 2. Visual Studio Code (VS Code) merupakan aplikasi yang digunakan untuk menulis, mengedit, dan menjalankan kode program..
# 3. GitHub merupakan layanan berbasis daring yang digunakan untuk menyimpan dan mengelola proyek. GitHub memungkinkan hasil pekerjaan disimpan secara daring sehingga dapat diakses dan dikelola kembali.

# %% [markdown]
# ## 2.2 Kode Program
#
# ### 2.2.1 Program "A_2611533023"
#
#
# Jalankan sel kode di bawah ini agar Jupyter otomatis menyimpan kodenya beserta outputnya sebagai satu kesatuan (tidak perlu screenshot terpisah untuk hasil run).

# %% [markdown]
# "tugas1_2611533023.py"

# %%
#program pertama
"""
komentar
dua baris atau lebih
pertemuan 1 praktikum alpro
"""
print("Hello world")
print()
print("program ini menghasilkan")
print("empat baris output")
print("/ \\ // \\\\ /// \\\\\\")
print("program ini" + "dibuat oleh a/n"+"Fadilatul Fitri 2611533023")
# Out:
# Hello world
#
# program ini menghasilkan
# empat baris output
# / \ // \\ /// \\\
# program inidibuat oleh a/nFadilatul Fitri 2611533023

# %% [markdown]
# **Penjelasan :**
# 1. Interpreter Python
# Interpreter Python berfungsi menerjemahkan dan menjalankan perintah yang ditulis menggunakan bahasa Python. Dengan interpreter, program yang telah dibuat dapat dijalankan dan menghasilkan output sesuai dengan perintah yang diberikan.
# 2. File Python
# File Python merupakan tempat untuk menyimpan program yang telah dibuat. File Python memiliki ekstensi .py dan dapat dibuat serta diedit melalui VS Code.
# 3. Repository
# Repository merupakan tempat penyimpanan suatu proyek yang dikelola menggunakan Git. Repository dapat berisi file program, dokumen, serta catatan perubahan yang berkaitan dengan proyek.
# 4. Commit
# Commit merupakan proses untuk mencatat perubahan yang telah dilakukan pada suatu proyek. Setiap commit dapat diberikan keterangan agar perubahan yang dilakukan dapat diketahui dengan jelas.
# 5. Push
# Push merupakan proses mengirimkan perubahan dari repository yang terdapat pada komputer ke repository yang terdapat di GitHub. Proses ini memungkinkan hasil pekerjaan yang telah dibuat dapat tersimpan pada GitHub.
# 6. Clone
# Clone merupakan proses menyalin repository dari GitHub ke komputer. Dengan melakukan clone, pengguna dapat memperoleh salinan proyek yang tersimpan di GitHub untuk kemudian dikerjakan atau dikembangkan kembali.

# %% [markdown]
# ---
# # BAB III
# # KESIMPULAN
#
# Berdasarkan praktikum yang telah dilakukan, dapat disimpulkan bahwa Python, VS Code, Git, dan GitHub memiliki fungsi yang saling berkaitan dalam proses pembuatan dan pengelolaan suatu program. Python digunakan sebagai bahasa pemrograman untuk membuat program, sedangkan VS Code digunakan untuk menulis dan menjalankan program. Git dan GitHub digunakan untuk mencatat perubahan serta menyimpan hasil pekerjaan.
# Praktikum ini menerapkan beberapa konsep dasar, seperti interpreter, repository, commit, push, dan clone. Pemahaman terhadap konsep tersebut membantu mahasiswa mengetahui tahapan dalam membuat, menyimpan, dan mengelola suatu program. Sehingga, praktikum ini dapat menjadi dasar dalam melaksanakan kegiatan pemrograman dan pengembangan proyek pada praktikum selanjutnya.

# %% [markdown]
# ---
# ## DAFTAR PUSTAKA
#
# [1] Microsoft, "Visual Studio Code Documentation," [Online]. Tersedia: https://code.visualstudio.com/docs⁠ [Diakses 2026].
#
# [2] Python Software Foundation, "The Python Tutorial," [Online]. Tersedia: https://docs.python.org/3/tutorial/⁠ [Diakses 2026].
#
# [3] GitHub, Inc., "Getting Started with GitHub," [Online]. Tersedia: https://docs.github.com/en/get-started⁠ [Diakses 2026].
#
# [4] Git, "Git Documentation," [Online]. Tersedia: https://git-scm.com/doc⁠ [Diakses 2026].
